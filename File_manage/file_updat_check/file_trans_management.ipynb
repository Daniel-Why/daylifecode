# %%
import os,time
from prettytable import PrettyTable
import shutil

# %%
def clear_path(target_path):
    # 清洗地址，去掉多余的"\"
    if target_path[-1] != "\\":
        target_path = target_path
    else:
        target_path = target_path[:-1]
    return target_path

# 展示数据
def show_list(table_list,list_type):# file_list :['文件名', '绝对路径', '相对路径','最近修改时间']
    n = 0
    for i in table_list:
        n += 1
        if list_type == "file_state":#文件格式:file_state :['文件名', '绝对路径', '相对路径','最近修改时间','状态']
            if i[-1] != "保持":
                print("{} | {} | {} ".format(n,i[-1],i[1]))
            else:
                continue
        elif list_type == "file_list":# file_list :['文件名', '绝对路径', '相对路径','最近修改时间']
            print("{} | {} | {} ".format(n,i[0],i[1]))
    print('''



    ''')

# 遍历指定目录下，文件夹的所有文件，并获取文件的创建、修改时间
## 提取文件的创建时间、修改时间
def getFileTime(file_ab_path):
    file_time_list  = []
    # 获取创建时间
    #file_time_list.append(os.path.getctime(file_ab_path)) 
    # 获取最近修改时间
    file_time_list.append(os.path.getmtime(file_ab_path))
    # 获取最近访问时间
    #file_time_list.append(os.path.getatime(file_ab_path))

    return file_time_list
## 将时间戳格式化为可读时间
def stamp2structTime(stamp_time):
    print(time.strftime('%Y-%m-%d %H:%M:%S',time.gmtime(stamp_time)))


## 判断目标文件夹绝对路径的字符串长度，用于后面提取文件的相对路径
def tp_string_len(target_path):
    if target_path[-1] != "\\":
        tp_string_len = len(target_path)
    else:
        tp_string_len = len(target_path)-1
    return tp_string_len


## 遍历指定路径下的文件，并提取文件名、绝对路径、相对路径及修改时间
def files_path_list(target_path):
    #root_list = []
    #dir_list = []
    file_list =[] #['文件名', '绝对路径', '相对路径','最近修改时间']
    for root,dirs,files in os.walk(target_path,topdown=False):
        #print(root)# 查询的根目录
        #print(dirs)# 根目录中的文件夹
        #print(files)# 根目录中的文件
        for f in files:
            f_data_list = []
            tp_len=tp_string_len(target_path)
            file_ab_path = root +"\\"+ f
            file_rel_path = file_ab_path[tp_len:]
            # 将文件信息写入列表
            f_data_list.append(f)#文件名
            f_data_list.append(file_ab_path )#绝对路径
            f_data_list.append(file_rel_path)#相对路径

            # 获取文件修改时间
            for file_time in getFileTime(file_ab_path):
                f_data_list.append(file_time)

            file_list.append(f_data_list)
    return(file_list)


# 对比相对路径下的文件，判断哪些文件需要迁移
def compare_files(org_file_list,target_file_list):
    for o_file in org_file_list:
        file_state = "添加"
        for t_file in target_file_list.copy():
            try:
                t_file.index(o_file[2])
            except:
                continue
            if o_file[3] != t_file[3]:
                file_state = "变更"
            else:
                file_state = "保持"
            target_file_list.remove(t_file)
            break
        o_file.append(file_state)
    for t_file in target_file_list:
        file_state = "移除"
        t_file.append(file_state)
        org_file_list.append(t_file)
    return org_file_list

# 执行迁移操作

## 选择更新模式
def update_file_mode(target_path,file_states_list):
    mode_id = input(
        '''请选择更新模式：
            1.添加、更新文件的同时删除目标文件夹中多余的文件
            2.仅添加和更新文件，不删除多余文件
        '''
    )
    update_file_list = file_states_list.copy()
    if mode_id == "1":
        pass
    elif mode_id == "2":
        for file in file_states_list:
            if file[-1] == "移除":
                print(file)
                update_file_list.remove(file)
            else:
                pass

    return update_file_list
    

## 判断文件夹是否存在，不存在则创建文件夹
def folder_exists(target_path):
    if not os.path.exists(target_path):
        os.makedirs(target_path)


## 执行迁移操作
def update_files(target_path,file_states_list):
    print("开始更新...")
    file_count = len(file_states_list)
    error_list = []
    n = 0
    for file in file_states_list:
        try:
            if file[-1]=="保持":#不更新文件
                pass
            elif file[-1]=="添加":
                #文件需要添加到的相对路径
                target_folder_path = (target_path+file[2])[:-len(file[0])]
                #print(target_folder_path)
                # 判断文件夹是否存在，不存在则创建文件夹
                folder_exists(target_folder_path)
                # shutil.copy2 能够对文件进行复制，同时不会修改文件的修改时间等属性
                shutil.copy2(file[1],target_path+file[2])
            elif file[-1]=="变更":
                shutil.copy2(file[1],target_path+file[2])
            elif file[-1]=="移除":
                os.remove(target_path+file[2])
        except:
            error_list.append(file)
        n += 1
        print("进度：{:.2%}".format(n/file_count),end='\r')

    print("\n完成更新")
    return error_list


# 删除目标目录中的空文件夹
def remove_empty_folder(target_path):
    target_path=clear_path(target_path)
    for root,dirs,files in os.walk(target_path,topdown=False):
        #print(root)# 查询的根目录
        #print(dirs)# 根目录中的文件夹
        #print(files)# 根目录中的文件
        try:
            if not os.listdir(root):# 非空为真，如果不为空则...
                #print('{} 是一个空文件夹'.format(root))
                os.removedirs(root)
                print('{} 已删除'.format(root))
        except:
            pass

    print("\n删除完成")


# Main Process
def update_file_process(org_path,target_path):

    # 清洗地址
    org_path = clear_path(org_path)
    target_path=clear_path(target_path)


    # 提取文件信息
    ## 源目录
    org_file_list = files_path_list(org_path)
    #print("#############源目录文件列表#############：")
    #show_list(org_file_list,"file_list")

    ## 目标目录
    target_file_list = files_path_list(target_path)
    #print("############目标目录文件列表###########：")
    #show_list(target_file_list,"file_list")

    # 比较原始文件夹和目标文件夹中的文件，列出文件更新状态
    file_states_list = compare_files(org_file_list,target_file_list)

    # 显示文件变更状态表格
    print("############文件更新状态：############")
    show_list(file_states_list,"file_state")


    # 选择模式，更新文档操作列表
    update_file_list = update_file_mode(target_path,file_states_list)
    print("############以下文件将进行更新：############")


    show_list(update_file_list,"file_state")
    operate_id = input("是否开始更新y/n:")
    if operate_id == "y":
        # 更新文件
        error_list = update_files(target_path,update_file_list)
        print("\n############以下文件更新失败：############")
        show_list(error_list,"file_state")
        # 删除目标目录中的空文件夹
        operate_id = input("是否删除目标目录中的所有空文件夹y/n:")
        if operate_id == "y":
            # 执行操作
            remove_empty_folder(target_path)
        else:
            print("结束脚本")
            # 执行操作     
    else:
        print("结束脚本")

# %%
# 主程序
if __name__ == '__main__':
    #样例地址：
    #org_path = r"E:\personal\daliy_code\daylifecode\File_manage\file_updat_check\test_file\org"
    #target_path = r"E:\personal\daliy_code\daylifecode\File_manage\file_updat_check\test_file\trans2"

    operate_id = input('''
    请选择模式（按任意键结束脚本）:
        1. 备份文件模式
        2. 清空空文件夹模式
        ''')
    if operate_id == "1":
        org_path = input("请输入原文件夹地址:")
        target_path=input("请输入目标文件夹地址:")
        # 二次确认
        second_confirm = input("确认将数据由\n{}\n备份至\n{}\n？确认则请输入'Confirm backup'!".format(org_path,target_path))
        if second_confirm == "Confirm backup":
            # 执行操作
            update_file_process(org_path,target_path)
        else:
            print("结束脚本")
    elif operate_id == "2":
        target_path=input("请输入目标文件夹地址:")
        remove_empty_folder(target_path)
    else:
        print("结束脚本")
# Out:
# ############文件更新状态：############
# 2424 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u1001.svg
# 2425 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u1001_mouseDown.svg
# 2426 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u1001_mouseOver.svg
# 2427 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u1001_selected.svg
# 2428 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u1004.svg
# 2429 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u1004_mouseDown.svg
# 2430 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u1004_mouseOver.svg
# 2431 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u1004_selected.svg
# 2432 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u1034.svg
# 2433 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u1034_mouseDown.svg
# 2434 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u1034_mouseOver.svg
# 2435 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u1034_selected.svg
# 2436 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u1036.svg
# 2437 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u1036_mouseDown.svg
# 2438 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u1036_mouseOver.svg
# 2439 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u1036_selected.svg
# 2440 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u261.svg
# 2441 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u262.svg
# 2442 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u263.svg
# 2443 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u279.svg
# 2444 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u279_disabled.svg
# 2445 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u279_mouseOver.svg
# 2446 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u281.svg
# 2447 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u281_disabled.svg
# 2448 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u281_mouseOver.svg
# 2449 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u283.svg
# 2450 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u283_disabled.svg
# 2451 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u284.svg
# 2452 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u284_disabled.svg
# 2453 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u284_mouseDown.svg
# 2454 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u284_mouseOver.svg
# 2455 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u287.svg
# 2456 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u289.svg
# 2457 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u291.svg
# 2458 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u309.svg
# 2459 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u310.svg
# 2460 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u658.svg
# 2461 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u863.svg
# 2462 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u863_disabled.svg
# 2463 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u863_mouseDown.svg
# 2464 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u863_mouseOver.svg
# 2465 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u887.svg
# 2466 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u887_disabled.svg
# 2467 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u887_mouseDown.svg
# 2468 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u887_mouseOver.svg
# 2469 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u890.svg
# 2470 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u890_disabled.svg
# 2471 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u890_mouseDown.svg
# 2472 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u890_mouseOver.svg
# 2473 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u893.svg
# 2474 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u893_disabled.svg
# 2475 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u893_mouseDown.svg
# 2476 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u893_mouseOver.svg
# 2477 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u909.svg
# 2478 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u909_disabled.svg
# 2479 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u909_mouseDown.svg
# 2480 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u909_mouseOver.svg
# 2481 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u913.svg
# 2482 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u913_disabled.svg
# 2483 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u913_mouseDown.svg
# 2484 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u913_mouseOver.svg
# 2485 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u917.svg
# 2486 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u931.svg
# 2487 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u933.svg
# 2488 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u939.svg
# 2489 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u940.svg
# 2490 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u940_mouseDown.svg
# 2491 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u940_mouseOver.svg
# 2492 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u940_selected.svg
# 2493 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u951.svg
# 2494 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u951_mouseDown.svg
# 2495 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u951_mouseOver.svg
# 2496 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u951_selected.svg
# 2497 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u962.svg
# 2498 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u962_mouseDown.svg
# 2499 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u962_mouseOver.svg
# 2500 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u962_selected.svg
# 2501 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u972.svg
# 2502 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u972_mouseDown.svg
# 2503 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u972_mouseOver.svg
# 2504 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u972_selected.svg
# 2505 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u977.svg
# 2506 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u977_mouseDown.svg
# 2507 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u977_mouseOver.svg
# 2508 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u977_selected.svg
# 2509 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u988.svg
# 2510 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u988_mouseDown.svg
# 2511 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u988_mouseOver.svg
# 2512 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u988_selected.svg
# 2513 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u998.svg
# 2514 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u998_mouseDown.svg
# 2515 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u998_mouseOver.svg
# 2516 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u998_selected.svg
# 2517 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\中继器选项_u868.svg
# 2518 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\中继器选项_u868_disabled.svg
# 2519 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\中继器选项_u868_mouseOver.svg
# 2520 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\可更新_u342.svg
# 2521 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\清空_u862.svg
# 4323 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u10170_focused.svg
# 4324 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u10170_selected.svg
# 4325 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u10170_selectedFocused.svg
# 4326 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u10171_focused.svg
# 4327 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u10171_selected.svg
# 4328 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u10171_selectedFocused.svg
# 4329 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u10172_focused.svg
# 4330 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u10172_selected.svg
# 4331 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u10172_selectedFocused.svg
# 4332 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u10445.svg
# 4333 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u10445_disabled.svg
# 4334 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u10445_mouseDown.svg
# 4335 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u10445_mouseOver.svg
# 4336 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u10452.svg
# 4337 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u10460.svg
# 4338 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u10460_disabled.svg
# 4339 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u10460_mouseDown.svg
# 4340 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u10460_mouseOver.svg
# 4341 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u10497.svg
# 4342 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u10497_disabled.svg
# 4343 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u10497_mouseDown.svg
# 4344 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u10497_mouseOver.svg
# 4345 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u10502.svg
# 4346 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u10582.svg
# 4347 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u10692.svg
# 4348 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u10712_menu.png
# 4349 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8642.png
# 4350 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8643.png
# 4351 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8644.png
# 4352 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8645.png
# 4353 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8646.png
# 4354 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8647.png
# 4355 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8648.png
# 4356 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8649.png
# 4357 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8650.png
# 4358 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8651.png
# 4359 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8652.png
# 4360 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8653.png
# 4361 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8654.png
# 4362 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8655.png
# 4363 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8656.png
# 4364 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8657.png
# 4365 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8658.png
# 4366 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8659.png
# 4367 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8660.png
# 4368 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8661.png
# 4369 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8662.png
# 4370 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8663.png
# 4371 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8664.png
# 4372 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8665.png
# 4373 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8666.png
# 4374 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8667.png
# 4375 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8668.png
# 4376 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8669.png
# 4377 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8866.png
# 4378 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8867.png
# 4379 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8868.png
# 4380 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8869.png
# 4381 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8870.png
# 4382 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8871.png
# 4383 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8872.png
# 4384 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8873.png
# 4385 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8874.png
# 4386 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8875.png
# 4387 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8876.png
# 4388 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8877.png
# 4389 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8878.png
# 4390 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8879.png
# 4391 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8882.svg
# 4392 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8882_disabled.svg
# 4393 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8882_mouseDown.svg
# 4394 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8882_mouseOver.svg
# 4395 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8883.svg
# 4396 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8954_focused.svg
# 4397 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8954_selected.svg
# 4398 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8954_selectedFocused.svg
# 4399 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8955_focused.svg
# 4400 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8955_selected.svg
# 4401 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8955_selectedFocused.svg
# 4402 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8956_focused.svg
# 4403 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8956_selected.svg
# 4404 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8956_selectedFocused.svg
# 4405 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9128_selected.svg
# 4406 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9227_focused.svg
# 4407 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9227_selected.svg
# 4408 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9227_selectedFocused.svg
# 4409 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9228_focused.svg
# 4410 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9228_selected.svg
# 4411 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9228_selectedFocused.svg
# 4412 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9229_focused.svg
# 4413 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9229_selected.svg
# 4414 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9229_selectedFocused.svg
# 4415 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9461_focused.svg
# 4416 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9461_selected.svg
# 4417 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9461_selectedFocused.svg
# 4418 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9462_focused.svg
# 4419 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9462_selected.svg
# 4420 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9462_selectedFocused.svg
# 4421 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9463_focused.svg
# 4422 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9463_selected.svg
# 4423 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9463_selectedFocused.svg
# 4424 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9688_focused.svg
# 4425 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9688_selected.svg
# 4426 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9688_selectedFocused.svg
# 4427 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9689_focused.svg
# 4428 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9689_selected.svg
# 4429 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9689_selectedFocused.svg
# 4430 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9690_focused.svg
# 4431 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9690_selected.svg
# 4432 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9690_selectedFocused.svg
# 4433 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\__choice1_u9022_focused.svg
# 4434 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\__choice1_u9022_selected.svg
# 4435 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\__choice1_u9022_selectedFocused.svg
# 4436 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\__choice1_u9053_focused.svg
# 4437 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\__choice1_u9053_selected.svg
# 4438 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\__choice1_u9053_selectedFocused.svg
# 4439 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\__choice1_u9853_focused.svg
# 4440 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\__choice1_u9853_selected.svg
# 4441 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\__choice1_u9853_selectedFocused.svg
# 4442 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\__choice1_u9986_focused.svg
# 4443 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\__choice1_u9986_selected.svg
# 4444 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\__choice1_u9986_selectedFocused.svg
# 4445 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\__choice2_u10017_focused.svg
# 4446 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\__choice2_u10017_selected.svg
# 4447 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\__choice2_u10017_selectedFocused.svg
# 4448 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\__choice2_u9084_focused.svg
# 4449 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\__choice2_u9084_selected.svg
# 4450 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\__choice2_u9084_selectedFocused.svg
# 4451 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\__choice2_u9884_focused.svg
# 4452 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\__choice2_u9884_selected.svg
# 4453 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\__choice2_u9884_selectedFocused.svg
# 4454 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\多选_u10451_selected-0.svg
# 4455 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\多选_u10451_selected-1.svg
# 4456 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\多选_u10451_selected-10.svg
# 4457 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\多选_u10451_selected-11.svg
# 4458 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\多选_u10451_selected-12.svg
# 4459 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\多选_u10451_selected-13.svg
# 4460 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\多选_u10451_selected-14.svg
# 4461 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\多选_u10451_selected-15.svg
# 4462 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\多选_u10451_selected-16.svg
# 4463 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\多选_u10451_selected-2.svg
# 4464 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\多选_u10451_selected-3.svg
# 4465 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\多选_u10451_selected-4.svg
# 4466 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\多选_u10451_selected-5.svg
# 4467 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\多选_u10451_selected-6.svg
# 4468 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\多选_u10451_selected-7.svg
# 4469 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\多选_u10451_selected-8.svg
# 4470 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\多选_u10451_selected-9.svg
# 4471 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\多选_u10451_selected.svg
# 7047 | 添加 | E:\work\nosugar\tanggo官网管理后台\prototype\TangGo官网管理后台_recovered.rp
# 14045 | 添加 | E:\work\nosugar\模糊测试工具\prototype\模糊测试工具2023-09-27_recovered.rp
# 14046 | 添加 | E:\work\nosugar\模糊测试工具\prototype\模糊测试工具_recovered.rp
# 14216 | 添加 | E:\work\nosugar\漏洞扫描\prototype\vuln_scan_recovered.rp
# 14837 | 变更 | E:\work\nosugar\漏洞验证工具\prototype\PoC_Tool.rp
# 14845 | 添加 | E:\work\nosugar\漏洞验证工具\prototype\PoC_Tool_20231026.rp
# 17457 | 移除 | G:\暂存2\work\nosugar\协同平台\文档资料\图\cooperative_platform\.git\objects\pack\pack-dd5bda8a7d62d7acaefcf98ba1c170cd5d6edb18.idx
# 17458 | 移除 | G:\暂存2\work\nosugar\协同平台\文档资料\图\cooperative_platform\.git\objects\pack\pack-dd5bda8a7d62d7acaefcf98ba1c170cd5d6edb18.pack
#
#
#
#
#
# ############以下文件将进行更新：############
# 2424 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u1001.svg
# 2425 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u1001_mouseDown.svg
# 2426 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u1001_mouseOver.svg
# 2427 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u1001_selected.svg
# 2428 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u1004.svg
# 2429 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u1004_mouseDown.svg
# 2430 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u1004_mouseOver.svg
# 2431 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u1004_selected.svg
# 2432 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u1034.svg
# 2433 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u1034_mouseDown.svg
# 2434 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u1034_mouseOver.svg
# 2435 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u1034_selected.svg
# 2436 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u1036.svg
# 2437 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u1036_mouseDown.svg
# 2438 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u1036_mouseOver.svg
# 2439 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u1036_selected.svg
# 2440 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u261.svg
# 2441 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u262.svg
# 2442 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u263.svg
# 2443 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u279.svg
# 2444 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u279_disabled.svg
# 2445 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u279_mouseOver.svg
# 2446 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u281.svg
# 2447 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u281_disabled.svg
# 2448 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u281_mouseOver.svg
# 2449 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u283.svg
# 2450 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u283_disabled.svg
# 2451 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u284.svg
# 2452 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u284_disabled.svg
# 2453 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u284_mouseDown.svg
# 2454 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u284_mouseOver.svg
# 2455 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u287.svg
# 2456 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u289.svg
# 2457 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u291.svg
# 2458 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u309.svg
# 2459 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u310.svg
# 2460 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u658.svg
# 2461 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u863.svg
# 2462 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u863_disabled.svg
# 2463 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u863_mouseDown.svg
# 2464 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u863_mouseOver.svg
# 2465 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u887.svg
# 2466 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u887_disabled.svg
# 2467 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u887_mouseDown.svg
# 2468 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u887_mouseOver.svg
# 2469 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u890.svg
# 2470 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u890_disabled.svg
# 2471 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u890_mouseDown.svg
# 2472 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u890_mouseOver.svg
# 2473 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u893.svg
# 2474 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u893_disabled.svg
# 2475 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u893_mouseDown.svg
# 2476 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u893_mouseOver.svg
# 2477 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u909.svg
# 2478 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u909_disabled.svg
# 2479 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u909_mouseDown.svg
# 2480 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u909_mouseOver.svg
# 2481 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u913.svg
# 2482 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u913_disabled.svg
# 2483 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u913_mouseDown.svg
# 2484 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u913_mouseOver.svg
# 2485 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u917.svg
# 2486 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u931.svg
# 2487 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u933.svg
# 2488 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u939.svg
# 2489 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u940.svg
# 2490 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u940_mouseDown.svg
# 2491 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u940_mouseOver.svg
# 2492 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u940_selected.svg
# 2493 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u951.svg
# 2494 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u951_mouseDown.svg
# 2495 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u951_mouseOver.svg
# 2496 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u951_selected.svg
# 2497 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u962.svg
# 2498 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u962_mouseDown.svg
# 2499 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u962_mouseOver.svg
# 2500 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u962_selected.svg
# 2501 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u972.svg
# 2502 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u972_mouseDown.svg
# 2503 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u972_mouseOver.svg
# 2504 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u972_selected.svg
# 2505 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u977.svg
# 2506 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u977_mouseDown.svg
# 2507 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u977_mouseOver.svg
# 2508 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u977_selected.svg
# 2509 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u988.svg
# 2510 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u988_mouseDown.svg
# 2511 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u988_mouseOver.svg
# 2512 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u988_selected.svg
# 2513 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u998.svg
# 2514 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u998_mouseDown.svg
# 2515 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u998_mouseOver.svg
# 2516 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u998_selected.svg
# 2517 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\中继器选项_u868.svg
# 2518 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\中继器选项_u868_disabled.svg
# 2519 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\中继器选项_u868_mouseOver.svg
# 2520 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\可更新_u342.svg
# 2521 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\清空_u862.svg
# 4323 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u10170_focused.svg
# 4324 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u10170_selected.svg
# 4325 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u10170_selectedFocused.svg
# 4326 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u10171_focused.svg
# 4327 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u10171_selected.svg
# 4328 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u10171_selectedFocused.svg
# 4329 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u10172_focused.svg
# 4330 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u10172_selected.svg
# 4331 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u10172_selectedFocused.svg
# 4332 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u10445.svg
# 4333 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u10445_disabled.svg
# 4334 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u10445_mouseDown.svg
# 4335 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u10445_mouseOver.svg
# 4336 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u10452.svg
# 4337 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u10460.svg
# 4338 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u10460_disabled.svg
# 4339 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u10460_mouseDown.svg
# 4340 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u10460_mouseOver.svg
# 4341 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u10497.svg
# 4342 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u10497_disabled.svg
# 4343 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u10497_mouseDown.svg
# 4344 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u10497_mouseOver.svg
# 4345 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u10502.svg
# 4346 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u10582.svg
# 4347 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u10692.svg
# 4348 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u10712_menu.png
# 4349 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8642.png
# 4350 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8643.png
# 4351 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8644.png
# 4352 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8645.png
# 4353 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8646.png
# 4354 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8647.png
# 4355 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8648.png
# 4356 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8649.png
# 4357 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8650.png
# 4358 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8651.png
# 4359 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8652.png
# 4360 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8653.png
# 4361 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8654.png
# 4362 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8655.png
# 4363 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8656.png
# 4364 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8657.png
# 4365 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8658.png
# 4366 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8659.png
# 4367 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8660.png
# 4368 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8661.png
# 4369 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8662.png
# 4370 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8663.png
# 4371 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8664.png
# 4372 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8665.png
# 4373 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8666.png
# 4374 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8667.png
# 4375 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8668.png
# 4376 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8669.png
# 4377 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8866.png
# 4378 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8867.png
# 4379 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8868.png
# 4380 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8869.png
# 4381 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8870.png
# 4382 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8871.png
# 4383 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8872.png
# 4384 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8873.png
# 4385 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8874.png
# 4386 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8875.png
# 4387 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8876.png
# 4388 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8877.png
# 4389 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8878.png
# 4390 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8879.png
# 4391 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8882.svg
# 4392 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8882_disabled.svg
# 4393 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8882_mouseDown.svg
# 4394 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8882_mouseOver.svg
# 4395 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8883.svg
# 4396 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8954_focused.svg
# 4397 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8954_selected.svg
# 4398 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8954_selectedFocused.svg
# 4399 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8955_focused.svg
# 4400 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8955_selected.svg
# 4401 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8955_selectedFocused.svg
# 4402 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8956_focused.svg
# 4403 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8956_selected.svg
# 4404 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8956_selectedFocused.svg
# 4405 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9128_selected.svg
# 4406 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9227_focused.svg
# 4407 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9227_selected.svg
# 4408 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9227_selectedFocused.svg
# 4409 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9228_focused.svg
# 4410 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9228_selected.svg
# 4411 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9228_selectedFocused.svg
# 4412 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9229_focused.svg
# 4413 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9229_selected.svg
# 4414 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9229_selectedFocused.svg
# 4415 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9461_focused.svg
# 4416 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9461_selected.svg
# 4417 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9461_selectedFocused.svg
# 4418 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9462_focused.svg
# 4419 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9462_selected.svg
# 4420 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9462_selectedFocused.svg
# 4421 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9463_focused.svg
# 4422 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9463_selected.svg
# 4423 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9463_selectedFocused.svg
# 4424 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9688_focused.svg
# 4425 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9688_selected.svg
# 4426 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9688_selectedFocused.svg
# 4427 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9689_focused.svg
# 4428 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9689_selected.svg
# 4429 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9689_selectedFocused.svg
# 4430 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9690_focused.svg
# 4431 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9690_selected.svg
# 4432 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9690_selectedFocused.svg
# 4433 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\__choice1_u9022_focused.svg
# 4434 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\__choice1_u9022_selected.svg
# 4435 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\__choice1_u9022_selectedFocused.svg
# 4436 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\__choice1_u9053_focused.svg
# 4437 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\__choice1_u9053_selected.svg
# 4438 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\__choice1_u9053_selectedFocused.svg
# 4439 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\__choice1_u9853_focused.svg
# 4440 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\__choice1_u9853_selected.svg
# 4441 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\__choice1_u9853_selectedFocused.svg
# 4442 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\__choice1_u9986_focused.svg
# 4443 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\__choice1_u9986_selected.svg
# 4444 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\__choice1_u9986_selectedFocused.svg
# 4445 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\__choice2_u10017_focused.svg
# 4446 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\__choice2_u10017_selected.svg
# 4447 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\__choice2_u10017_selectedFocused.svg
# 4448 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\__choice2_u9084_focused.svg
# 4449 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\__choice2_u9084_selected.svg
# 4450 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\__choice2_u9084_selectedFocused.svg
# 4451 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\__choice2_u9884_focused.svg
# 4452 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\__choice2_u9884_selected.svg
# 4453 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\__choice2_u9884_selectedFocused.svg
# 4454 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\多选_u10451_selected-0.svg
# 4455 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\多选_u10451_selected-1.svg
# 4456 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\多选_u10451_selected-10.svg
# 4457 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\多选_u10451_selected-11.svg
# 4458 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\多选_u10451_selected-12.svg
# 4459 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\多选_u10451_selected-13.svg
# 4460 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\多选_u10451_selected-14.svg
# 4461 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\多选_u10451_selected-15.svg
# 4462 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\多选_u10451_selected-16.svg
# 4463 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\多选_u10451_selected-2.svg
# 4464 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\多选_u10451_selected-3.svg
# 4465 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\多选_u10451_selected-4.svg
# 4466 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\多选_u10451_selected-5.svg
# 4467 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\多选_u10451_selected-6.svg
# 4468 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\多选_u10451_selected-7.svg
# 4469 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\多选_u10451_selected-8.svg
# 4470 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\多选_u10451_selected-9.svg
# 4471 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\多选_u10451_selected.svg
# 7047 | 添加 | E:\work\nosugar\tanggo官网管理后台\prototype\TangGo官网管理后台_recovered.rp
# 14045 | 添加 | E:\work\nosugar\模糊测试工具\prototype\模糊测试工具2023-09-27_recovered.rp
# 14046 | 添加 | E:\work\nosugar\模糊测试工具\prototype\模糊测试工具_recovered.rp
# 14216 | 添加 | E:\work\nosugar\漏洞扫描\prototype\vuln_scan_recovered.rp
# 14837 | 变更 | E:\work\nosugar\漏洞验证工具\prototype\PoC_Tool.rp
# 14845 | 添加 | E:\work\nosugar\漏洞验证工具\prototype\PoC_Tool_20231026.rp
# 17457 | 移除 | G:\暂存2\work\nosugar\协同平台\文档资料\图\cooperative_platform\.git\objects\pack\pack-dd5bda8a7d62d7acaefcf98ba1c170cd5d6edb18.idx
# 17458 | 移除 | G:\暂存2\work\nosugar\协同平台\文档资料\图\cooperative_platform\.git\objects\pack\pack-dd5bda8a7d62d7acaefcf98ba1c170cd5d6edb18.pack
#
#
#
#
#
# 开始更新...
# 进度：100.00%
# 完成更新
#
# ############以下文件更新失败：############
# 1 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u1036_mouseDown.svg
# 2 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u1036_mouseOver.svg
# 3 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u1036_selected.svg
# 4 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u261.svg
# 5 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u262.svg
# 6 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u263.svg
# 7 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u279.svg
# 8 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u279_disabled.svg
# 9 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u279_mouseOver.svg
# 10 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u281.svg
# 11 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u281_disabled.svg
# 12 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u281_mouseOver.svg
# 13 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u283.svg
# 14 | 添加 | E:\work\nosugar\axure_show\TangGo主程序\images\application\u283_disabled.svg
# 15 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u10497_mouseDown.svg
# 16 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u10497_mouseOver.svg
# 17 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u10502.svg
# 18 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u10582.svg
# 19 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u10692.svg
# 20 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u10712_menu.png
# 21 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8649.png
# 22 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8650.png
# 23 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8651.png
# 24 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8652.png
# 25 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8653.png
# 26 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8654.png
# 27 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8655.png
# 28 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8656.png
# 29 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8657.png
# 30 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8658.png
# 31 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8659.png
# 32 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8660.png
# 33 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8661.png
# 34 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8662.png
# 35 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8663.png
# 36 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8664.png
# 37 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8665.png
# 38 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8666.png
# 39 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8667.png
# 40 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8668.png
# 41 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8669.png
# 42 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8866.png
# 43 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8867.png
# 44 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8868.png
# 45 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8869.png
# 46 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8870.png
# 47 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8871.png
# 48 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8872.png
# 49 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8873.png
# 50 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8874.png
# 51 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8875.png
# 52 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8876.png
# 53 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8877.png
# 54 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8878.png
# 55 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8879.png
# 56 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8882.svg
# 57 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8882_disabled.svg
# 58 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8882_mouseDown.svg
# 59 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8882_mouseOver.svg
# 60 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8883.svg
# 61 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8954_selected.svg
# 62 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8954_selectedFocused.svg
# 63 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8955_focused.svg
# 64 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8955_selected.svg
# 65 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8955_selectedFocused.svg
# 66 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8956_focused.svg
# 67 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8956_selected.svg
# 68 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u8956_selectedFocused.svg
# 69 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9128_selected.svg
# 70 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9227_focused.svg
# 71 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9227_selected.svg
# 72 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9227_selectedFocused.svg
# 73 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9228_focused.svg
# 74 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9228_selected.svg
# 75 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9228_selectedFocused.svg
# 76 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9229_focused.svg
# 77 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9229_selected.svg
# 78 | 添加 | E:\work\nosugar\axure_show\漏洞扫描工具\images\扫描结果\u9229_selectedFocused.svg
# 79 | 移除 | G:\暂存2\work\nosugar\协同平台\文档资料\图\cooperative_platform\.git\objects\pack\pack-dd5bda8a7d62d7acaefcf98ba1c170cd5d6edb18.idx
# 80 | 移除 | G:\暂存2\work\nosugar\协同平台\文档资料\图\cooperative_platform\.git\objects\pack\pack-dd5bda8a7d62d7acaefcf98ba1c170cd5d6edb18.pack
#
#
#
#
#
# G:\暂存2\work\nosugar\axure_show\HTTP模糊测试工具\images\延迟等待指定时间 已删除
# G:\暂存2\work\nosugar\axure_show\HTTP模糊测试工具\images\执行js脚本处理数据 已删除
# G:\暂存2\work\nosugar\axure_show\HTTP模糊测试工具\images\除去html标签 已删除
# G:\暂存2\work\nosugar\axure_show\编码加密解密工具\images\2 已删除
#
# 删除完成
